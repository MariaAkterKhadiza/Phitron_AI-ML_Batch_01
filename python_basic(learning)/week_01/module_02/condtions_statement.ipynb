# %%
raining = False
if raining == True:
    print("raincoat is need")
    print("caution")
else:
    print("go without raincoat")
    print("This is a sunnyDay")
# Out:
# go without raincoat
# This is a sunnyDay

# %%
raining = True
Muddy = True

if raining == True:
    print("raincoat is need")
    if Muddy == True:
        print("Sandal is needed")
    else:
        print("Bring Snakers")
else:
    print("go without raincoat")
    print("This is a sunnyDay")
# Out:
# raincoat is need
# Sandal is needed

# %%
taka = 1000
# 500 ar besi hole gorte jabo
#400 ar besi hole food order korbo basay
#300 ar besi hole food court a jabo
#er cheye kom thakle saving


if taka > 500 :
    print("Gorte jabo")
elif taka > 400:
    print("Basay order korbo")
elif taka > 300:
    print("Food court a jabo")
else:
    print("Taka saving korbo")
# Out:
# Gorte jabo
