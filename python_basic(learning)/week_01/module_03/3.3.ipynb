# %% [markdown]
# strinf methods

# %%
string ="welcome to phitron ML course phitron"

#length
print(len(string))
# Out:
# 36

# %% [markdown]
# search word

# %%
print("phitron" in string)
# Out:
# False

# %%
procees_string = string.lower()
print("phitron" in procees_string)
# Out:
# True

# %% [markdown]
# index kin jaiga theke soro seta dekhar jonno

# %%
fast_index = procees_string.find("phitron")
print(fast_index)
# Out:
# 11

# %% [markdown]
# ses dik theke kon index soro hoice

# %%
last_index = procees_string.rfind("phitron")
print(last_index)
# Out:
# 11

# %%
processed_string ="hi bangladesh i love bangladesh"

count = processed_string.count("love")

print(count)
# Out:
# 1

# %% [markdown]
# replace substring

# %%
new_string = string.replace("ML","AI/ML")
print(new_string)
# Out:
# welcome to Phitron AI/ML course phitron
