# %%
#declaration
numbers = [100,20,30,40,50] #int
float_numbers = [10.2,20.4,30.5,40.6,50.8,.34]
print(type(float_numbers))
# Out:
# <class 'list'>

# %%
##access
print(numbers[2])
numbers[2] = 90
print(numbers[2])

new_list = numbers[0:3]
print(new_list)
# Out:
# 30
# 90
# [100, 20, 90]

# %% [markdown]
# #modification

# %%
#append (last a digit add kora jai)
numbers.append(80)
print(numbers)

#insert(index bole dite hoy_position bole dite hoy and ager digit right side a shift hoye jabe)
numbers.insert(0,45)
print(numbers)


#value last position a delete korar jonno (pop)
numbers.pop()
print(numbers)

#remove
numbers.remove(100)
print(numbers)


print(type(float_numbers))
# Out:
# [100, 20, 90, 40, 50, 80]
# [45, 100, 20, 90, 40, 50, 80]
# [45, 100, 20, 90, 40, 50]
# [45, 20, 90, 40, 50]
