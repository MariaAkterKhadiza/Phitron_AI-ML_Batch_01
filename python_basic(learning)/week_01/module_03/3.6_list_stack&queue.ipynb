# %% [markdown]
# #sort

# %%
numbers =[23,9,12,45,80,70]
numbers.sort()
print(numbers)
# Out:
# [9, 12, 23, 45, 70, 80]

# %%
numbers.sort(reverse = True)
print(numbers)
# Out:
# [80, 70, 45, 23, 12, 9]

# %% [markdown]
# stack __FILO

# %%
## stack in list
stack = []

#stack in push
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)
#stack in pop
stack.pop()
stack.pop()
stack.pop()
stack.pop()

#type(stack)
# Out:
# 2

# %% [markdown]
# ##list in queue

# %%
## queue
## queue in list
queue = []

#queue in push
queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)
queue.append(5)
#queue in pop
queue.pop()
queue.pop()
queue.pop()
queue.pop()

#type(stack)
# Out:
# 2
