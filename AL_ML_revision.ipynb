# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaAkterKhadiza/Phitron_AI-ML_Batch_01/blob/main/AL_ML_revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variable

# %%
name = "Maria Dewan"
age = 28
price = 99.99

print(name)
print(age)
print(price)

name = "phitron"
age_2 = 20

print(age, type(age))
# Out:
# Maria Dewan
# 28
# 99.99
# 28 <class 'int'>

# %% [markdown]
# # variable and Data type

# %%
phone_number = 1909047892
print(phone_number)
# Out:
# 1909047892

# %%
name = "maria"
print(name)
# Out:
# maria

# %%
age = 20
height = 5.4
name = "Maria"
is_passed = True

print(type(age), type(height), type(name),type(is_passed))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %% [markdown]
# # Taking Input in python

# %%
name = input("what is your name ?")
print(name)
# Out:
# what is your name ?mariya
# mariya

# %%
age = input("Age ?")
print(age, type(age))
# Out:
# Age ?22
# 22 <class 'str'>

# %%
age = input("Age ?")
age = int(age)
print(age, type(age))
# Out:
# Age ?23
# 23 <class 'int'>

# %%
height = input("Height ?")
print(height, type(height))
# Out:
# Height ?90
# 90 <class 'str'>

# %%
height = float(input("Height ?"))
print(height , type(height))
# Out:
# Height ?22
# 22.0 <class 'float'>

# %%
height = height + 0.2
print(height)
print(type(height))
# Out:
# 22.4
# <class 'float'>

# %%
x = 10
y = 3

sum = x + y
sub = x - y
mult = x * y
div = x / y
remand = x % y # remainded
print(sum,sub,mult,div, remand)
# Out:
# 13 7 30 3.3333333333333335 1

# %%
x = 10; y = 3

greater_than = x > y
greater_than_equal = (10 >= 10)
print(greater_than)
print(greater_than_equal)

less_than = x < y
less_than_qual = (10 <= 10)
print(less_than)
print(less_than_qual)

equal =  x==y

print(equal)


not_equal = x != y

print(not_equal)
# Out:
# True
# True
# False
# True
# False
# True

# %% [markdown]
# # logical **Operator**

# %%
x = 10; y = 5; z = 3
result = (x > y) and (x > z)
print(result)
# Out:
# True

# %%
x = 10; y = 5; z=15
result = (x > y) and (z > y)
print(result)
# Out:
# True

# %%
x = 10; y = 5; z=15
result = (x > y) or (z > y)
print(result)
# Out:
# True

# %% [markdown]
# # Precedence and Associativity

# %%
eq = 10 + 10/2 - 5*2
print(eq)
# Out:
# 5.0

# %% [markdown]
# # problem

# %%
inp  = input()
numbers = inp.splite()

x = int(numbers[0])
y = int(numbers[1])

last_digit_of_x = x % 10
last_digit_of_y = y % 10

sum = last_digit_of_x + last_digit_of_y

print(sum)
# Out:
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4271073541.py in <cell line: 0>()
#       1 inp  = input()
# ----> 2 numbers = inp.splite()
#       3
#       4 x = int(numbers[0])
#       5 y = int(numbers[1])
#
# AttributeError: 'str' object has no attribute 'splite'
